# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# Histogram

data = [32, 96,45,34]
plt.hist(data)
plt.show()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# Histogram

data = [32, 96,45,34]
lab = ["Investment","Returns","Profit","Express"]
explode =[0,0,0.1,0]
plt.pie(data,labels =lab, explode=explode,shadow=True)
plt.show()
