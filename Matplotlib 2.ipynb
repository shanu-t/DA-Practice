# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
plt.xlabel("sales in Months")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
plt.xlabel("sales in Months")
plt.ylabel("Rupees in Thousands")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
plt.xlabel("sales in Months")
plt.ylabel("Rupees in Thousands")
plt.title("Sales in Month")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1)
plt.ylabel("Rupees in Thousands",fontdict=font2)

plt.title("Sales in Month")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1,loc="right")
plt.ylabel("Rupees in Thousands",fontdict=font2)

plt.title("Sales in Month")
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1,loc="right")
plt.ylabel("Rupees in Thousands",fontdict=font2)

plt.title("Sales in Month")
plt.grid(axis="y")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,45,334,34,34]
months =["Jan","Feb","Mar","Apr","May"]

plt.plot(months,sales)
font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1,loc="right")
plt.ylabel("Rupees in Thousands",fontdict=font2)

plt.title("Sales in Month")
plt.grid(axis="x")
plt.show()

# %%
#subplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales1 = [23,6,35,24,45]
months1 =["Jan","Feb","Mar","Apr","May"]
sales2 = [32,56,14,74,51]
months2 =["Jan","Feb","Mar","Apr","May"]


font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1,loc="right")
plt.ylabel("Rupees in Thousands",fontdict=font2)

plt.title("Sales in Month")
plt.plot(months1,sales1)
plt.subplot(1,2,1)
plt.plot(months2,sales2)
plt.subplot(1,2,2)
plt.show()

# %%
#subplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sales = [23,6,35,24,45]
months =["Jan","Feb","Mar","Apr","May"]
plt.subplot(1,2,1)
plt.plot(sales,months)
font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1,loc="right")
plt.ylabel("Rupees in Thousands",fontdict=font2)


sales = [32,56,14,74,51]
months =["Jan","Feb","Mar","Apr","May"]
plt.subplot(1,2,2)
plt.plot(sales,months)


font1={"family":"arial","color":"red","size":10}
font2 ={"family":"arial","color":"green","size":10}
plt.xlabel("sales in Months",fontdict=font1,loc="right")
plt.ylabel("Rupees in Thousands",fontdict=font2)

plt.title("Sales in Month")
plt.plot(months1,sales1)
plt.subplot(1,2,1)
plt.plot(months2,sales2)
plt.subplot(1,2,2)
plt.show()

# %%
#subplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,1)
plt.plot(x,y)

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,2)
plt.plot(x,y)

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,3)
plt.plot(x,y)

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,4)
plt.plot(x,y)

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,5)
plt.plot(x,y)

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,6)
plt.plot(x,y)

plt.suptitle("Data by numbers")
plt.show()

# %%
#subplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("sales")

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.title("spend")

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.title("Income")

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,4)
plt.plot(x,y)
x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,5)
plt.plot(x,y)

x = np.array([3,5,8,3,6,8])
y =np.array([27,65,78,89,42,43])
plt.subplot(2,3,6)
plt.plot(x,y)

plt.suptitle("Data by numbers")
plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,7,4,4,7,8])
y = np.array([12,54,68,24,56,78,43,56,87])

plt.plot(x,y)
plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,7,4,4,7,8])
y = np.array([12,54,68,24,56,78,43,56,87])

plt.scatter(x,y,marker="*")
plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,7,4,4,7,8])
y = np.array([12,54,68,24,56,78,43,56,87])

plt.scatter(x,y,marker="*",color="red")
plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,5,5,6,6,6,7,1,4,6,7,8])
y = np.array([12,54,68,24,23,87,67,56,87,98,45,67,34,34,56])

color= np.arange(1,100,7)

plt.scatter(x,y,c=color)


plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,5,5,6,6,6,7,1,4,6,7,8])
y = np.array([12,54,68,24,23,87,67,56,87,98,45,67,34,34,56])

color= np.arange(1,100,7)

plt.scatter(x,y,c=color,cmap="hsv")


plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,5,5,6,6,6,7,1,4,6,7,8])
y = np.array([12,54,68,24,23,87,67,56,87,98,45,67,34,34,56])

color= np.arange(1,100,7)

plt.scatter(x,y,c=color,cmap="plasma")
plt.colorbar()


plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,5,5,6,6,6,7,1,4,6,7,8])
y = np.array([12,54,68,24,23,87,67,56,87,98,45,67,34,34,56])

color= np.arange(1,100,7)

plt.scatter(x,y,c=color,cmap="hsv",s=20)
plt.colorbar()

plt.show()

# %%
# subplot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,3,4,2,5,5,6,6,6,7,1,4,6,7,8])
y = np.array([12,54,68,24,23,87,67,56,87,98,45,67,34,34,56])

color= np.arange(1,100,7)

plt.scatter(x,y,c=color,cmap="hsv",s=20,alpha=1)
plt.colorbar()

plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = [10,40,56,34,76]
y = ["jan","feb","mar","apr","may"]
plt.bar(x,y)

plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = [10,40,56,34,76]
y = ["jan","feb","mar","apr","may"]
plt.barh(x,y)

plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = [10,40,56,34,76]
y = ["jan","feb","mar","apr","may"]
plt.bar(y,x)

plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = [10,40,56,34,76]
y = ["jan","feb","mar","apr","may"]
plt.barh(y,x)

plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
x = [10,40,56,34,76]
y = ["jan","feb","mar","apr","may"]
plt.barh(y,x,color="#ff0066")
plt.show()
